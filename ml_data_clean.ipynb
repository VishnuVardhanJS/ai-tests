# %%
import pandas as pd

data = pd.read_csv("housing.csv")

data1 = data[:1000]

data1.head(1000)


#pip3 install --upgrade https://storage.googleapis.com/tensorflow/mac/cpu/tensorflow-1.0.0-py3-none-any.whl
# Out:
#      longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0      -122.23     37.88                41.0        880.0           129.0
# 1      -122.22     37.86                21.0       7099.0          1106.0
# 2      -122.24     37.85                52.0       1467.0           190.0
# 3      -122.25     37.85                52.0       1274.0           235.0
# 4      -122.25     37.85                52.0       1627.0           280.0
# ..         ...       ...                 ...          ...             ...
# 995    -121.75     37.71                11.0      12070.0          2220.0
# 996    -121.77     37.74                25.0        494.0            81.0
# 997    -121.80     37.70                22.0       5533.0           943.0
# 998    -121.80     37.69                17.0       3956.0           639.0
# 999    -121.82     37.69                12.0       1906.0           351.0
#
#      population  households  median_income  median_house_value ocean_proximity
# 0         322.0       126.0         8.3252            452600.0        NEAR BAY
# 1        2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2         496.0       177.0         7.2574            352100.0        NEAR BAY
# 3         558.0       219.0         5.6431            341300.0        NEAR BAY
# 4         565.0       259.0         3.8462            342200.0        NEAR BAY
# ..          ...         ...            ...                 ...             ...
# 995      5826.0      2125.0         4.8624            192400.0          INLAND
# 996       254.0        85.0         9.1531            418800.0          INLAND
# 997      2474.0       910.0         4.7361            216800.0          INLAND
# 998      2222.0       662.0         5.4324            215500.0          INLAND
# 999       802.0       319.0         4.9375            227700.0          INLAND
#
# [1000 rows x 10 columns]
